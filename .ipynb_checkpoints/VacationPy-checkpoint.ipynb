# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import ipywidgets 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import os
import math
import gmaps
import gmaps.datasets
import json
from pandas import json_normalize
from pprint import pprint
import seaborn as sns

# Import API key

from api_key import crime_key
from api_key import geoc_key

# %%
statesAbbr = ["AL","AK","AZ", "AR","CA","CO","CT", "DE","FL","GA", "HI", "ID", "IL","IN", "IA","KS", 
          "KY","LA","ME","MD","MA","MI","MN", "MS","MO","MT", "NE","NV","NH","NJ","NM","NY","NC",
          "ND","OH","OK","OR","PA","RI","SC","SD","TN","TX","UT","VT","VA","WA","WV","WI","WY"]

url = "https://api.usa.gov/crime/fbi/sapi/api/states?API_KEY=hRdZ9LTpBdt4uN9wXdDEv4WLJ6LEnndOyy7qyC8M"
url2 = "https://api.usa.gov/crime/fbi/sapi/api/data/nibrs/all-offenses/offender/states/TX/age?API_KEY=hRdZ9LTpBdt4uN9wXdDEv4WLJ6LEnndOyy7qyC8M"
url3 = "https://api.usa.gov/crime/fbi/sapi/api/data/nibrs/all-offenses/offense/national/CRIMINAL_ACTIVITY?API_KEY=hRdZ9LTpBdt4uN9wXdDEv4WLJ6LEnndOyy7qyC8M"
url4 = "https://api.crimeometer.com/v1/incidents/raw-data?lat=lat&lon=lon&distance=distance&datetime_ini=datetime_ini&datetime_end=datetime_end&page=page?API_KEY=hRdZ9LTpBdt4uN9wXdDEv4WLJ6LEnndOyy7qyC8M"

# %%
r = requests.get(url3)
print(r.status_code)
# Out:
# 200

# %%
r.json()
# Out:
# {'results': [{'buying__receiving': 0,
#    'cultivating__manufacturing__publishing': 0,
#    'distributing__selling': 0,
#    'exploiting_children': 0,
#    'operating__promoting__assisting': 0,
#    'possessing__concealing': 0,
#    'transporting__transmitting__importing': 0,
#    'using__consuming': 0,
#    'none__unknown': 24802,
#    'other_gang': 44,
#    'juvenile_gang': 53,
#    'simple__gross_neglect': 0,
#    'organized_aninal_abuse': 0,
#    'intentional_abuse_and_torture': 0,
#    'animal_sexual_abuse': 0,
#    'data_year': 1998},
#   {'buying__receiving': 2720,
#    'cultivating__manufacturing__publishing': 0,
#    'distributing__selling': 18946,
#    'exploiting_children': 35,
#    'operating__promoting__assisting': 488,
#    'possessing__concealing': 89078,
#    'transporting__transmitting__importing': 2103,
#    'using__consuming': 9259,
#    'none__unknown': 0,
#    'other_gang': 0,
#    'juvenile_gang': 0,
#    'simple__gross_neglect': 0,
# ...

# %%
r.json().keys()
# Out:
# dict_keys(['results', 'pagination'])

# %%
r.json()['results']
df = json_normalize()
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-45c71a36fcbb> in <module>
#       1 r.json()['results']
# ----> 2 df = json_normalize()
#       3 df
#
# TypeError: _json_normalize() missing 1 required positional argument: 'data'

# %%
df = json_normalize(results)
df.head(482)
